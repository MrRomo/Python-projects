# %%
import argparse
import os
import face_recognition
import numpy as np
import sklearn
import pickle
from face_recognition import face_locations
from PIL import Image, ImageDraw, ImageFont
from tqdm import tqdm
import cv2
import pandas as pd
import math

# import unicodedata
#cap = cv2.VideoCapture(0)
#leido, frame = cap.read()

frame = cv2.imread('Hombre.jpg')
frame = cv2.imread('Anteojos.png')
frame = cv2.imread('Asiatico.jpg')
frame = cv2.imread('Niño.jpeg')
frame = cv2.imread('Mujer.jpeg')
frame = cv2.imread('Bebe.jpeg')
frame = cv2.imread('Sindy1.jpeg')
frame = cv2.imread('Sindy2.jpeg')
frame = cv2.imread('Padre.jpeg')
frame = cv2.imread('Bebe1.jpeg')
frame = cv2.imread('p6.jpg')

#img = cv2.imread('Bebe1.jpg',cv2.IMREAD_GRAYSCALE )
#cv2.imshow('Imagen',img)

class PersonClassifier:

    def __init__(self):
        self.frame = frame
        self.race = None   
        self.gender = None
        self.age = None    
        self.ColorHair= None
        self.Glasses= None
        self.COLS = ['Male', 'Asian', 'White', 'Black',  'Baby', 'Child', 'Youth', 'Middle Aged', 'Senior', 'Black Hair', 'Blond Hair', 'Brown Hair', 'Bald', 'No eyewear', 'Eyeglasses', 'Sunglasses', 'Mustache', 'Smiling','Curly Hair', 'Wavy Hair', 'Straight Hair']
        self.N_UPSCLAE = 1
        self.model_path =('race_and_gender_model.pkl') # args.model

                #predecir una imagen
    def predict_one_image(self,img_path, clf, labels):
        print("2. predict_one_image")
        print(" ")

        """Predict face attributes for all detected faces in one image"""
        print("Predecir atributos de cara para todas las caras detectadas en una imagen.")
        
        face_encodings, locs = self.extract_features(img_path)
        #print(face_encodings, locs)
        
        
        if not face_encodings:
            return None, None
        pred = pd.DataFrame(clf.predict_proba(face_encodings),
                            columns = labels)
        #print(pred)
        pred = pred.loc[:, self.COLS]
        #print("Fin pred")
        print ("2.pred",pred)
        print ("2.locs",locs)
        print("_2. End predict_one_image ")
        print(" ")

        return pred, locs
        
    def gender_race(self,frame):
        with open(self.model_path) as f:

            clf, labels = pickle.load(f)
            print(clf)
            pred, locs = self.predict_one_image(frame, clf, labels)
            print(" ")
            print("pred")
            print(pred)
            locs = \
                pd.DataFrame(locs, columns = ['top', 'right', 'bottom', 'left'])
            df = pd.concat([pred, locs], axis=1)
            print("End pred")

            print(" ")
            #print("Imprimiendo DF")
            #print(df)
            img,gender_race = self.draw_attributes(frame, df)
        return gender_race
        print("0. gender_race")   
        #diccionario= {'Genero':None,'raza':None}
        
    #extraer_características
    def extract_features(self,img_path):
        print("3. extraer_características")
        print(" ")
        """Exctract 128 dimensional features"""
        print("Extraer 128 características dimensionales.")
        
        locs = face_locations(img_path, number_of_times_to_upsample = self.N_UPSCLAE)
        print(locs)
        if len(locs) == 0:
            return None, None
        face_encodings = face_recognition.face_encodings(frame, known_face_locations=locs)
        #print ("face_encodings",face_encodings)
        #print ("locs",locs)
        print("_3. End extract_features")

        return face_encodings, locs
 
    #dibujar atributos
    def draw_attributes(self,img_path, df):
        print(" ")
        print("4. dibujar atributos")
        print(" ")

        """Write bounding boxes and predicted face attributes on the image"""
        print("Escribe cuadros delimitadores y atributos de cara predichos en la imagen.")
        
        img = img_path 
        
        #nmedWindow( "Display window", CV_WINDOW_AUTOSIZE );
        #imshow( "Display window", image );
        #cv2.imread(img_path)
        #img2  = cv2.cvtColor(color, cv2.COLOR_BGR2RGB)
        for row in df.iterrows():
            caracteristicas=len(row[1])
            Car=caracteristicas-4
            print(row[1][Car:].astype(int))
            top, right, bottom, left = row[1][Car:].astype(int)
              
            print("row")
            print(type(row)) 
            print(row)
            print("")
            self.setGender(row[1]['Male'])
            self.setRace(np.argmax(row[1][1:4]))
            self.setAge(np.argmax(row[1][4:9]))
            self.setColorHair(np.argmax(row[1][9:13]))
            print("Asasasas")
            print(type(row[1][13]))
            self.setGlasses(row[1][13],np.argmax(row[1][13:16]))
            text_showed = "{} {}".format(self.race, self.gender)
            #print (text_showed)
            Features = {'Gender':self.gender,'Race':self.race,'Age':self.age,'ColorHair':self.ColorHair,'Glasses':self.Glasses}
            cv2.rectangle(img, (left, top), (right, bottom), (0, 0, 255), 2)
            font = cv2.FONT_HERSHEY_DUPLEX
            img_width = img.shape[1]
            cv2.putText(img, text_showed, (left + 6, bottom - 6), font, 0.5, (255, 255, 255), 1)
            #print ("img",img)
            print ("4. Features",Features)
            print("_4. End draw_attributes ")
            print(" ")

        return img,Features
    
    def setGender(self,EstGender):

        if EstGender >= 0.5:
            self.gender = 'Male'
        else:
            self.gender = 'Female'

    def getGender(self):
        return self.gender

    def setRace(self,EstRace):
        self.race = EstRace

    def getRace(self):
        return self.race

    def setAge(self,EstAge):
        self.age = EstAge

    def getAge(self):
        return self.age

    def setColorHair(self,EstColorHair):
        self.ColorHair= EstColorHair

    def getColorHair(self):
        return self.ColorHair   
    
    def setGlasses(self,NoEyewear,EstGlasses):
        if math.isnan(NoEyewear):
            self.Glasses= 'No Eyewear'
        else: 
            self.Glasses= EstGlasses

    def getGlasses(self):
        return self.Glasses
    
PersonC=PersonClassifier()    
Features = PersonC.gender_race(frame)
print("Final Process")
print(" ")
#print('Gender:', PersonC.getGender() ,'race:',PersonC.getRace())
#print('Age:',PersonC.getAge(),'ColorHair:',PersonC.getColorHair())
#print('Glasses:',PersonC.getGlasses())
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        n_iter_no_change=None, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.001,
#        validation_fraction=0.1, verbose=True, warm_start=False)
# 2. predict_one_image
#
# Predecir atributos de cara para todas las caras detectadas en una imagen.
# 3. extraer_características
#
# Extraer 128 características dimensionales.
# /home/mrromo16/anaconda3/envs/pepper/lib/python2.7/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.18.1 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/mrromo16/anaconda3/envs/pepper/lib/python2.7/site-packages/sklearn/base.py:253: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.18.1 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a4baf2c7451b> in <module>()
#     193
#     194 PersonC=PersonClassifier()
# --> 195 Features = PersonC.gender_race(frame)
#     196 print("Final Process")
#     197 print(" ")
#
# <ipython-input-1-a4baf2c7451b> in gender_race(self, frame)
#      75             clf, labels = pickle.load(f)
#      76             print(clf)
# ---> 77             pred, locs = self.predict_one_image(frame, clf, labels)
#      78             print(" ")
#      79             print("pred")
#
# <ipython-input-1-a4baf2c7451b> in predict_one_image(self, img_path, clf, labels)
#      52         print("Predecir atributos de cara para todas las caras detectadas en una imagen.")
#      53
# ---> 54         face_encodings, locs = self.extract_features(img_path)
#      55         #print(face_encodings, locs)
#      56
#
# <ipython-input-1-a4baf2c7451b> in extract_features(self, img_path)
#      98         print("Extraer 128 características dimensionales.")
#      99
# --> 100         locs = face_locations(img_path, number_of_times_to_upsample = self.N_UPSCLAE)
#     101         print(locs)
#     102         if len(locs) == 0:
#
# /home/mrromo16/anaconda3/envs/pepper/lib/python2.7/site-packages/face_recognition/api.pyc in face_locations(img, number_of_times_to_upsample, model)
#     116         return [_trim_css_to_bounds(_rect_to_css(face.rect), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, "cnn")]
#     117     else:
# --> 118         return [_trim_css_to_bounds(_rect_to_css(face), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, model)]
#     119
#     120
#
# /home/mrromo16/anaconda3/envs/pepper/lib/python2.7/site-packages/face_recognition/api.pyc in _raw_face_locations(img, number_of_times_to_upsample, model)
#     100         return cnn_face_detector(img, number_of_times_to_upsample)
#     101     else:
# --> 102         return face_detector(img, number_of_times_to_upsample)
#     103
#     104
#
# TypeError: __call__(): incompatible function arguments. The following argument types are supported:
#     1. (self: dlib.fhog_object_detector, image: array, upsample_num_times: int=0L) -> dlib.rectangles
#
# Invoked with: <dlib.fhog_object_detector object at 0x7f8304069e30>, None, 1

# %%
def ClasificadorDeFotos(tam):
    intro='p'
    ext='.jpg'
    cont=0
    dfList=list()
    tam=7
    for index in range(tam):
        print(" ")
        print("ENTRENAMIENTO ", index+1)
        print(" ")
        nombre = intro + str(index+1) + ext
        PersonC=PersonClassifier()    
        img=cv2.imread(nombre,3)
        Features = PersonC.gender_race(img)
        Features['Nombre']=nombre
        print("Final Process")
        print(" ")
        df = pd.DataFrame([[Features[key] for key in Features.keys()]], index=range(tam), columns= Features.keys())
        dfList.append(df)
        print(" ")
    df = pd.concat(dfList)
    return df

# %%
df=ClasificadorDeFotos(7)
# Out:
#
# ('ENTRENAMIENTO ', 1)
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        n_iter_no_change=None, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.001,
#        validation_fraction=0.1, verbose=True, warm_start=False)
# 2. predict_one_image
#
# Predecir atributos de cara para todas las caras detectadas en una imagen.
# 3. extraer_características
#
# Extraer 128 características dimensionales.
# [(160L, 778L, 345L, 593L), (192L, 513L, 415L, 291L), (211L, 1013L, 340L, 884L)]
# _3. End extract_features
# ('2.pred',        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.978762  0.004809  0.853002  0.038659  0.003877  0.006186  0.006387
# 1  0.965765  0.003808  0.702018  0.007717  0.003778  0.041451  0.043440
# 2  0.978901  0.011048  0.840872  0.022604  0.004678  0.003653  0.001867
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.108030  0.446270    0.008320  ...    0.279655  0.208305         NaN
# 1     0.089201  0.007498    0.110757  ...    0.571208  0.045705         NaN
# 2     0.136367  0.616179    0.018461  ...    0.252102  0.175266         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.818855    0.011903  0.922093  0.253769    0.752516   0.611301
# 1    0.654951    0.025296  0.418486  0.224745    0.624412   0.241226
# 2    0.559329    0.003260  0.958717  0.310142    0.853236   0.362368
#
#    Straight Hair
# 0       0.249961
# 1       0.403954
# 2       0.281379
#
# [3 rows x 21 columns])
# ('2.locs', [(160L, 778L, 345L, 593L), (192L, 513L, 415L, 291L), (211L, 1013L, 340L, 884L)])
# _2. End predict_one_image
#
#
# pred
#        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.978762  0.004809  0.853002  0.038659  0.003877  0.006186  0.006387
# 1  0.965765  0.003808  0.702018  0.007717  0.003778  0.041451  0.043440
# 2  0.978901  0.011048  0.840872  0.022604  0.004678  0.003653  0.001867
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.108030  0.446270    0.008320  ...    0.279655  0.208305         NaN
# 1     0.089201  0.007498    0.110757  ...    0.571208  0.045705         NaN
# 2     0.136367  0.616179    0.018461  ...    0.252102  0.175266         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.818855    0.011903  0.922093  0.253769    0.752516   0.611301
# 1    0.654951    0.025296  0.418486  0.224745    0.624412   0.241226
# 2    0.559329    0.003260  0.958717  0.310142    0.853236   0.362368
#
#    Straight Hair
# 0       0.249961
# 1       0.403954
# 2       0.281379
#
# [3 rows x 21 columns]
# End pred
#
#
# 4. dibujar atributos
#
# Escribe cuadros delimitadores y atributos de cara predichos en la imagen.
# top       160
# right     778
# bottom    345
# left      593
# Name: 0, dtype: int64
# row
# <type 'tuple'>
# (0, Male               0.978762
# Asian              0.004809
# White              0.853002
# Black              0.038659
# Baby               0.003877
# Child              0.006186
# Youth              0.006387
# Middle Aged        0.108030
# Senior             0.446270
# Black Hair         0.008320
# Blond Hair         0.007025
# Brown Hair         0.279655
# Bald               0.208305
# No eyewear              NaN
# Eyeglasses         0.818855
# Sunglasses         0.011903
# Mustache           0.922093
# Smiling            0.253769
# Curly Hair         0.752516
# Wavy Hair          0.611301
# Straight Hair      0.249961
# top              160.000000
# right            778.000000
# bottom           345.000000
# left             593.000000
# Name: 0, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Senior', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# top       192
# right     513
# bottom    415
# left      291
# Name: 1, dtype: int64
# row
# <type 'tuple'>
# (1, Male               0.965765
# Asian              0.003808
# White              0.702018
# Black              0.007717
# Baby               0.003778
# Child              0.041451
# Youth              0.043440
# Middle Aged        0.089201
# Senior             0.007498
# Black Hair         0.110757
# Blond Hair         0.001578
# Brown Hair         0.571208
# Bald               0.045705
# No eyewear              NaN
# Eyeglasses         0.654951
# Sunglasses         0.025296
# Mustache           0.418486
# Smiling            0.224745
# Curly Hair         0.624412
# Wavy Hair          0.241226
# Straight Hair      0.403954
# top              192.000000
# right            513.000000
# bottom           415.000000
# left             291.000000
# Name: 1, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Middle Aged', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# top        211
# right     1013
# bottom     340
# left       884
# Name: 2, dtype: int64
# row
# <type 'tuple'>
# (2, Male                0.978901
# Asian               0.011048
# White               0.840872
# Black               0.022604
# Baby                0.004678
# Child               0.003653
# Youth               0.001867
# Middle Aged         0.136367
# Senior              0.616179
# Black Hair          0.018461
# Blond Hair          0.002349
# Brown Hair          0.252102
# Bald                0.175266
# No eyewear               NaN
# Eyeglasses          0.559329
# Sunglasses          0.003260
# Mustache            0.958717
# Smiling             0.310142
# Curly Hair          0.853236
# Wavy Hair           0.362368
# Straight Hair       0.281379
# top               211.000000
# right            1013.000000
# bottom            340.000000
# left              884.000000
# Name: 2, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Senior', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# Final Process
#
#
#
# ('ENTRENAMIENTO ', 2)
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        n_iter_no_change=None, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.001,
#        validation_fraction=0.1, verbose=True, warm_start=False)
# 2. predict_one_image
#
# Predecir atributos de cara para todas las caras detectadas en una imagen.
# 3. extraer_características
#
# Extraer 128 características dimensionales.
# [(98L, 270L, 253L, 115L)]
# _3. End extract_features
# ('2.pred',        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.974837  0.002968  0.735476  0.005833  0.005945  0.043225  0.013151
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0      0.08585  0.018957    0.066402  ...    0.474439  0.046829         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.739754    0.022131  0.249433  0.163968    0.675089   0.276896
#
#    Straight Hair
# 0       0.354188
#
# [1 rows x 21 columns])
# ('2.locs', [(98L, 270L, 253L, 115L)])
# _2. End predict_one_image
#
#
# pred
#        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.974837  0.002968  0.735476  0.005833  0.005945  0.043225  0.013151
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0      0.08585  0.018957    0.066402  ...    0.474439  0.046829         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.739754    0.022131  0.249433  0.163968    0.675089   0.276896
#
#    Straight Hair
# 0       0.354188
#
# [1 rows x 21 columns]
# End pred
#
#
# 4. dibujar atributos
#
# Escribe cuadros delimitadores y atributos de cara predichos en la imagen.
# top        98
# right     270
# bottom    253
# left      115
# Name: 0, dtype: int64
# row
# <type 'tuple'>
# (0, Male               0.974837
# Asian              0.002968
# White              0.735476
# Black              0.005833
# Baby               0.005945
# Child              0.043225
# Youth              0.013151
# Middle Aged        0.085850
# Senior             0.018957
# Black Hair         0.066402
# Blond Hair         0.001501
# Brown Hair         0.474439
# Bald               0.046829
# No eyewear              NaN
# Eyeglasses         0.739754
# Sunglasses         0.022131
# Mustache           0.249433
# Smiling            0.163968
# Curly Hair         0.675089
# Wavy Hair          0.276896
# Straight Hair      0.354188
# top               98.000000
# right            270.000000
# bottom           253.000000
# left             115.000000
# Name: 0, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Middle Aged', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# Final Process
#
#
#
# ('ENTRENAMIENTO ', 3)
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        n_iter_no_change=None, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.001,
#        validation_fraction=0.1, verbose=True, warm_start=False)
# 2. predict_one_image
#
# Predecir atributos de cara para todas las caras detectadas en una imagen.
# 3. extraer_características
#
# Extraer 128 características dimensionales.
# [(617L, 2427L, 1576L, 1469L)]
# _3. End extract_features
# ('2.pred',        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.962937  0.013541  0.450804  0.022294  0.003697  0.037751  0.025679
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.037243  0.040908    0.040377  ...    0.307573  0.079388         NaN
#
#    Eyeglasses  Sunglasses  Mustache  Smiling  Curly Hair  Wavy Hair  \
# 0      0.7917    0.030776  0.256754  0.23729    0.471787    0.43402
#
#    Straight Hair
# 0        0.46811
#
# [1 rows x 21 columns])
# ('2.locs', [(617L, 2427L, 1576L, 1469L)])
# _2. End predict_one_image
#
#
# pred
#        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.962937  0.013541  0.450804  0.022294  0.003697  0.037751  0.025679
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.037243  0.040908    0.040377  ...    0.307573  0.079388         NaN
#
#    Eyeglasses  Sunglasses  Mustache  Smiling  Curly Hair  Wavy Hair  \
# 0      0.7917    0.030776  0.256754  0.23729    0.471787    0.43402
#
#    Straight Hair
# 0        0.46811
#
# [1 rows x 21 columns]
# End pred
#
#
# 4. dibujar atributos
#
# Escribe cuadros delimitadores y atributos de cara predichos en la imagen.
# top        617
# right     2427
# bottom    1576
# left      1469
# Name: 0, dtype: int64
# row
# <type 'tuple'>
# (0, Male                0.962937
# Asian               0.013541
# White               0.450804
# Black               0.022294
# Baby                0.003697
# Child               0.037751
# Youth               0.025679
# Middle Aged         0.037243
# Senior              0.040908
# Black Hair          0.040377
# Blond Hair          0.003874
# Brown Hair          0.307573
# Bald                0.079388
# No eyewear               NaN
# Eyeglasses          0.791700
# Sunglasses          0.030776
# Mustache            0.256754
# Smiling             0.237290
# Curly Hair          0.471787
# Wavy Hair           0.434020
# Straight Hair       0.468110
# top               617.000000
# right            2427.000000
# bottom           1576.000000
# left             1469.000000
# Name: 0, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Senior', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# Final Process
#
#
#
# ('ENTRENAMIENTO ', 4)
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        n_iter_no_change=None, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.001,
#        validation_fraction=0.1, verbose=True, warm_start=False)
# 2. predict_one_image
#
# Predecir atributos de cara para todas las caras detectadas en una imagen.
# 3. extraer_características
#
# Extraer 128 características dimensionales.
# [(57L, 407L, 242L, 221L), (98L, 614L, 253L, 459L), (39L, 741L, 168L, 612L), (152L, 151L, 259L, 44L)]
# _3. End extract_features
# ('2.pred',        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.956877  0.002283  0.776795  0.008489  0.004185  0.043918  0.037241
# 1  0.973282  0.003655  0.752905  0.006480  0.005275  0.038995  0.023881
# 2  0.921461  0.014983  0.693737  0.035487  0.007701  0.018956  0.039609
# 3  0.981013  0.001956  0.835143  0.005232  0.006633  0.040814  0.011530
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.088753  0.008127    0.083172  ...    0.541552  0.061767         NaN
# 1     0.064614  0.018030    0.064967  ...    0.469222  0.045673         NaN
# 2     0.037895  0.115001    0.027417  ...    0.252296  0.235179         NaN
# 3     0.113105  0.018948    0.051612  ...    0.477571  0.070402         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.564832    0.024616  0.351989  0.238798    0.634764   0.292379
# 1    0.741418    0.020329  0.220874  0.169498    0.677730   0.293716
# 2    0.805866    0.014597  0.243742  0.344310    0.612219   0.494906
# 3    0.709496    0.023048  0.309825  0.119930    0.675473   0.274094
#
#    Straight Hair
# 0       0.365542
# 1       0.326089
# 2       0.362564
# 3       0.352826
#
# [4 rows x 21 columns])
# ('2.locs', [(57L, 407L, 242L, 221L), (98L, 614L, 253L, 459L), (39L, 741L, 168L, 612L), (152L, 151L, 259L, 44L)])
# _2. End predict_one_image
#
#
# pred
#        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.956877  0.002283  0.776795  0.008489  0.004185  0.043918  0.037241
# 1  0.973282  0.003655  0.752905  0.006480  0.005275  0.038995  0.023881
# 2  0.921461  0.014983  0.693737  0.035487  0.007701  0.018956  0.039609
# 3  0.981013  0.001956  0.835143  0.005232  0.006633  0.040814  0.011530
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.088753  0.008127    0.083172  ...    0.541552  0.061767         NaN
# 1     0.064614  0.018030    0.064967  ...    0.469222  0.045673         NaN
# 2     0.037895  0.115001    0.027417  ...    0.252296  0.235179         NaN
# 3     0.113105  0.018948    0.051612  ...    0.477571  0.070402         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.564832    0.024616  0.351989  0.238798    0.634764   0.292379
# 1    0.741418    0.020329  0.220874  0.169498    0.677730   0.293716
# 2    0.805866    0.014597  0.243742  0.344310    0.612219   0.494906
# 3    0.709496    0.023048  0.309825  0.119930    0.675473   0.274094
#
#    Straight Hair
# 0       0.365542
# 1       0.326089
# 2       0.362564
# 3       0.352826
#
# [4 rows x 21 columns]
# End pred
#
#
# 4. dibujar atributos
#
# Escribe cuadros delimitadores y atributos de cara predichos en la imagen.
# top        57
# right     407
# bottom    242
# left      221
# Name: 0, dtype: int64
# row
# <type 'tuple'>
# (0, Male               0.956877
# Asian              0.002283
# White              0.776795
# Black              0.008489
# Baby               0.004185
# Child              0.043918
# Youth              0.037241
# Middle Aged        0.088753
# Senior             0.008127
# Black Hair         0.083172
# Blond Hair         0.002767
# Brown Hair         0.541552
# Bald               0.061767
# No eyewear              NaN
# Eyeglasses         0.564832
# Sunglasses         0.024616
# Mustache           0.351989
# Smiling            0.238798
# Curly Hair         0.634764
# Wavy Hair          0.292379
# Straight Hair      0.365542
# top               57.000000
# right            407.000000
# bottom           242.000000
# left             221.000000
# Name: 0, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Middle Aged', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# top        98
# right     614
# bottom    253
# left      459
# Name: 1, dtype: int64
# row
# <type 'tuple'>
# (1, Male               0.973282
# Asian              0.003655
# White              0.752905
# Black              0.006480
# Baby               0.005275
# Child              0.038995
# Youth              0.023881
# Middle Aged        0.064614
# Senior             0.018030
# Black Hair         0.064967
# Blond Hair         0.001831
# Brown Hair         0.469222
# Bald               0.045673
# No eyewear              NaN
# Eyeglasses         0.741418
# Sunglasses         0.020329
# Mustache           0.220874
# Smiling            0.169498
# Curly Hair         0.677730
# Wavy Hair          0.293716
# Straight Hair      0.326089
# top               98.000000
# right            614.000000
# bottom           253.000000
# left             459.000000
# Name: 1, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Middle Aged', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# top        39
# right     741
# bottom    168
# left      612
# Name: 2, dtype: int64
# row
# <type 'tuple'>
# (2, Male               0.921461
# Asian              0.014983
# White              0.693737
# Black              0.035487
# Baby               0.007701
# Child              0.018956
# Youth              0.039609
# Middle Aged        0.037895
# Senior             0.115001
# Black Hair         0.027417
# Blond Hair         0.015479
# Brown Hair         0.252296
# Bald               0.235179
# No eyewear              NaN
# Eyeglasses         0.805866
# Sunglasses         0.014597
# Mustache           0.243742
# Smiling            0.344310
# Curly Hair         0.612219
# Wavy Hair          0.494906
# Straight Hair      0.362564
# top               39.000000
# right            741.000000
# bottom           168.000000
# left             612.000000
# Name: 2, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Senior', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# top       152
# right     151
# bottom    259
# left       44
# Name: 3, dtype: int64
# row
# <type 'tuple'>
# (3, Male               0.981013
# Asian              0.001956
# White              0.835143
# Black              0.005232
# Baby               0.006633
# Child              0.040814
# Youth              0.011530
# Middle Aged        0.113105
# Senior             0.018948
# Black Hair         0.051612
# Blond Hair         0.002466
# Brown Hair         0.477571
# Bald               0.070402
# No eyewear              NaN
# Eyeglasses         0.709496
# Sunglasses         0.023048
# Mustache           0.309825
# Smiling            0.119930
# Curly Hair         0.675473
# Wavy Hair          0.274094
# Straight Hair      0.352826
# top              152.000000
# right            151.000000
# bottom           259.000000
# left              44.000000
# Name: 3, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Middle Aged', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# Final Process
#
#
#
# ('ENTRENAMIENTO ', 5)
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        n_iter_no_change=None, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.001,
#        validation_fraction=0.1, verbose=True, warm_start=False)
# 2. predict_one_image
#
# Predecir atributos de cara para todas las caras detectadas en una imagen.
# 3. extraer_características
#
# Extraer 128 características dimensionales.
# [(142L, 761L, 365L, 538L)]
# _3. End extract_features
# ('2.pred',        Male     Asian   White     Black      Baby     Child     Youth  \
# 0  0.979245  0.002821  0.9275  0.007094  0.011965  0.009063  0.002839
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.095223  0.267278    0.015291  ...    0.390867  0.227258         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.837703    0.005212  0.466209  0.136391    0.770106   0.463321
#
#    Straight Hair
# 0       0.239622
#
# [1 rows x 21 columns])
# ('2.locs', [(142L, 761L, 365L, 538L)])
# _2. End predict_one_image
#
#
# pred
#        Male     Asian   White     Black      Baby     Child     Youth  \
# 0  0.979245  0.002821  0.9275  0.007094  0.011965  0.009063  0.002839
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.095223  0.267278    0.015291  ...    0.390867  0.227258         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.837703    0.005212  0.466209  0.136391    0.770106   0.463321
#
#    Straight Hair
# 0       0.239622
#
# [1 rows x 21 columns]
# End pred
#
#
# 4. dibujar atributos
#
# Escribe cuadros delimitadores y atributos de cara predichos en la imagen.
# top       142
# right     761
# bottom    365
# left      538
# Name: 0, dtype: int64
# row
# <type 'tuple'>
# (0, Male               0.979245
# Asian              0.002821
# White              0.927500
# Black              0.007094
# Baby               0.011965
# Child              0.009063
# Youth              0.002839
# Middle Aged        0.095223
# Senior             0.267278
# Black Hair         0.015291
# Blond Hair         0.002293
# Brown Hair         0.390867
# Bald               0.227258
# No eyewear              NaN
# Eyeglasses         0.837703
# Sunglasses         0.005212
# Mustache           0.466209
# Smiling            0.136391
# Curly Hair         0.770106
# Wavy Hair          0.463321
# Straight Hair      0.239622
# top              142.000000
# right            761.000000
# bottom           365.000000
# left             538.000000
# Name: 0, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Senior', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# Final Process
#
#
#
# ('ENTRENAMIENTO ', 6)
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        n_iter_no_change=None, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.001,
#        validation_fraction=0.1, verbose=True, warm_start=False)
# 2. predict_one_image
#
# Predecir atributos de cara para todas las caras detectadas en una imagen.
# 3. extraer_características
#
# Extraer 128 características dimensionales.
# [(143L, 1016L, 605L, 553L)]
# _3. End extract_features
# ('2.pred',        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.738154  0.030434  0.005353  0.907529  0.003301  0.204626  0.095889
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.007705  0.006547    0.168254  ...    0.233063  0.073968         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.036767    0.007041  0.056453  0.490521    0.219008   0.271767
#
#    Straight Hair
# 0        0.72741
#
# [1 rows x 21 columns])
# ('2.locs', [(143L, 1016L, 605L, 553L)])
# _2. End predict_one_image
#
#
# pred
#        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.738154  0.030434  0.005353  0.907529  0.003301  0.204626  0.095889
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.007705  0.006547    0.168254  ...    0.233063  0.073968         NaN
#
#    Eyeglasses  Sunglasses  Mustache   Smiling  Curly Hair  Wavy Hair  \
# 0    0.036767    0.007041  0.056453  0.490521    0.219008   0.271767
#
#    Straight Hair
# 0        0.72741
#
# [1 rows x 21 columns]
# End pred
#
#
# 4. dibujar atributos
#
# Escribe cuadros delimitadores y atributos de cara predichos en la imagen.
# top        143
# right     1016
# bottom     605
# left       553
# Name: 0, dtype: int64
# row
# <type 'tuple'>
# (0, Male                0.738154
# Asian               0.030434
# White               0.005353
# Black               0.907529
# Baby                0.003301
# Child               0.204626
# Youth               0.095889
# Middle Aged         0.007705
# Senior              0.006547
# Black Hair          0.168254
# Blond Hair          0.001481
# Brown Hair          0.233063
# Bald                0.073968
# No eyewear               NaN
# Eyeglasses          0.036767
# Sunglasses          0.007041
# Mustache            0.056453
# Smiling             0.490521
# Curly Hair          0.219008
# Wavy Hair           0.271767
# Straight Hair       0.727410
# top               143.000000
# right            1016.000000
# bottom            605.000000
# left              553.000000
# Name: 0, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Child', 'Race': 'Black', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# Final Process
#
#
#
# ('ENTRENAMIENTO ', 7)
#
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        n_iter_no_change=None, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.001,
#        validation_fraction=0.1, verbose=True, warm_start=False)
# 2. predict_one_image
#
# Predecir atributos de cara para todas las caras detectadas en una imagen.
# 3. extraer_características
#
# Extraer 128 características dimensionales.
# [(1043L, 1682L, 2002L, 723L), (958L, 3354L, 1757L, 2555L)]
# _3. End extract_features
# ('2.pred',        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.962937  0.013541  0.450804  0.022294  0.003697  0.037751  0.025679
# 1  0.962937  0.013541  0.450804  0.022294  0.003697  0.037751  0.025679
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.037243  0.040908    0.040377  ...    0.307573  0.079388         NaN
# 1     0.037243  0.040908    0.040377  ...    0.307573  0.079388         NaN
#
#    Eyeglasses  Sunglasses  Mustache  Smiling  Curly Hair  Wavy Hair  \
# 0      0.7917    0.030776  0.256754  0.23729    0.471787    0.43402
# 1      0.7917    0.030776  0.256754  0.23729    0.471787    0.43402
#
#    Straight Hair
# 0        0.46811
# 1        0.46811
#
# [2 rows x 21 columns])
# ('2.locs', [(1043L, 1682L, 2002L, 723L), (958L, 3354L, 1757L, 2555L)])
# _2. End predict_one_image
#
#
# pred
#        Male     Asian     White     Black      Baby     Child     Youth  \
# 0  0.962937  0.013541  0.450804  0.022294  0.003697  0.037751  0.025679
# 1  0.962937  0.013541  0.450804  0.022294  0.003697  0.037751  0.025679
#
#    Middle Aged    Senior  Black Hair  ...  Brown Hair      Bald  No eyewear  \
# 0     0.037243  0.040908    0.040377  ...    0.307573  0.079388         NaN
# 1     0.037243  0.040908    0.040377  ...    0.307573  0.079388         NaN
#
#    Eyeglasses  Sunglasses  Mustache  Smiling  Curly Hair  Wavy Hair  \
# 0      0.7917    0.030776  0.256754  0.23729    0.471787    0.43402
# 1      0.7917    0.030776  0.256754  0.23729    0.471787    0.43402
#
#    Straight Hair
# 0        0.46811
# 1        0.46811
#
# [2 rows x 21 columns]
# End pred
#
#
# 4. dibujar atributos
#
# Escribe cuadros delimitadores y atributos de cara predichos en la imagen.
# top       1043
# right     1682
# bottom    2002
# left       723
# Name: 0, dtype: int64
# row
# <type 'tuple'>
# (0, Male                0.962937
# Asian               0.013541
# White               0.450804
# Black               0.022294
# Baby                0.003697
# Child               0.037751
# Youth               0.025679
# Middle Aged         0.037243
# Senior              0.040908
# Black Hair          0.040377
# Blond Hair          0.003874
# Brown Hair          0.307573
# Bald                0.079388
# No eyewear               NaN
# Eyeglasses          0.791700
# Sunglasses          0.030776
# Mustache            0.256754
# Smiling             0.237290
# Curly Hair          0.471787
# Wavy Hair           0.434020
# Straight Hair       0.468110
# top              1043.000000
# right            1682.000000
# bottom           2002.000000
# left              723.000000
# Name: 0, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Senior', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# top        958
# right     3354
# bottom    1757
# left      2555
# Name: 1, dtype: int64
# row
# <type 'tuple'>
# (1, Male                0.962937
# Asian               0.013541
# White               0.450804
# Black               0.022294
# Baby                0.003697
# Child               0.037751
# Youth               0.025679
# Middle Aged         0.037243
# Senior              0.040908
# Black Hair          0.040377
# Blond Hair          0.003874
# Brown Hair          0.307573
# Bald                0.079388
# No eyewear               NaN
# Eyeglasses          0.791700
# Sunglasses          0.030776
# Mustache            0.256754
# Smiling             0.237290
# Curly Hair          0.471787
# Wavy Hair           0.434020
# Straight Hair       0.468110
# top               958.000000
# right            3354.000000
# bottom           1757.000000
# left             2555.000000
# Name: 1, dtype: float64)
#
# Asasasas
# <type 'numpy.float64'>
# ('4. Features', {'Gender': 'Male', 'Age': 'Senior', 'Race': 'White', 'ColorHair': 'Brown Hair', 'Glasses': 'No Eyewear'})
# _4. End draw_attributes
#
# Final Process

# %%
df
# Out:
#   Gender          Age   Race  Nombre   ColorHair     Glasses
# 0   Male       Senior  White  p1.jpg  Brown Hair  No Eyewear
# 0   Male  Middle Aged  White  p2.jpg  Brown Hair  No Eyewear
# 0   Male       Senior  White  p3.jpg  Brown Hair  No Eyewear
# 0   Male  Middle Aged  White  p4.jpg  Brown Hair  No Eyewear
# 0   Male       Senior  White  p5.jpg  Brown Hair  No Eyewear
# 0   Male        Child  Black  p6.jpg  Brown Hair  No Eyewear
# 0   Male       Senior  White  p7.jpg  Brown Hair  No Eyewear

# %%
index= range(7)

# %%
index
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
print(type(Features))
# Out:
# <type 'dict'>

# %%
df= pd.Series(Features)

# %%
df.values
# Out:
# array(['Child', 'Brown Hair', 'Male', 'No Eyewear', 'Black'], dtype=object)

# %%
df.index
# Out:
# Index([u'Age', u'ColorHair', u'Gender', u'Glasses', u'Race'], dtype='object')

# %%
df = pd.DataFrame(data=df.values,columns=df.index)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-a5e4d89bf951> in <module>()
# ----> 1 df = pd.DataFrame(data=df.values,columns=df.index)
#       2 df
#
# /home/jarvis-skynet/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     422             else:
#     423                 mgr = init_ndarray(data, index, columns, dtype=dtype,
# --> 424                                    copy=copy)
#     425
#     426         # For data is list-like, or Iterable (will consume into list)
#
# /home/jarvis-skynet/anaconda2/lib/python2.7/site-packages/pandas/core/internals/construction.pyc in init_ndarray(values, index, columns, dtype, copy)
#     165         values = maybe_infer_to_datetimelike(values)
#     166
# --> 167     return create_block_manager_from_blocks([values], [columns, index])
#     168
#     169
#
# /home/jarvis-skynet/anaconda2/lib/python2.7/site-packages/pandas/core/internals/managers.pyc in create_block_manager_from_blocks(blocks, axes)
#    1658         blocks = [getattr(b, 'values', b) for b in blocks]
#    1659         tot_items = sum(b.shape[0] for b in blocks)
# -> 1660         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1661
#    1662
#
# /home/jarvis-skynet/anaconda2/lib/python2.7/site-packages/pandas/core/internals/managers.pyc in construction_error(tot_items, block_shape, axes, e)
#    1689         raise ValueError("Empty data passed with indices specified.")
#    1690     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 1691         passed, implied))
#    1692
#    1693
#
# ValueError: Shape of passed values is (5, 1), indices imply (5, 5)

# %%
df = pd.DataFrame([[Features[key] for key in Features.keys()]], columns= Features.keys())
df
# Out:
#   Gender    Age   Race   ColorHair     Glasses
# 0   Male  Child  Black  Brown Hair  No Eyewear

# %%
cd Neural-Class\Aditional\
# Out:
# [Errno 2] No such file or directory: 'Neural-ClassAditional'
# /home/jarvis-skynet/Neural-Class/Aditional

# %%
cd Aditional\
# Out:
# [Errno 2] No such file or directory: 'Aditional '
# /home/jarvis-skynet/Neural-Class/Aditional

# %%
ls
# Out:
# Hombre.jpg  Prueba.ipynb  race_and_gender_model.pkl  race and gender.py

# %%
Features.keys()
# Out:
# ['Gender', 'Age', 'Race', 'ColorHair', 'Glasses']

# %%
    clients = {
        "Waldon Astling": 1.83,
        "Catherine MacTerlagh": 0.15,
        "Gusty Wondraschek": 9.19,
        "Lois Vaan": 1.28,
        "Baird Eberts": 0.82,
        "Amalia Flieg": 2.88,
        "Leontine Wildbore": 9.44,
        "Rikki Chasteney": 7.01,
        "Augustine Papierz": 0.22,
        "Maynord Lawrance": 0.33
    }

# %%
[[key, Features[key]] for key in Features.keys()]
# Out:
# [['Gender', 'Male'],
#  ['Age', 'Child'],
#  ['Race', 'Black'],
#  ['ColorHair', 'Brown Hair'],
#  ['Glasses', 'No Eyewear']]

# %%
[[Features[key] for key in Features.keys()]]
# Out:
# [['Male', 'Child', 'Black', 'Brown Hair', 'No Eyewear']]

# %%
df
# Out:
#   Gender    Age   Race   ColorHair     Glasses
# 0   Male  Child  Black  Brown Hair  No Eyewear
